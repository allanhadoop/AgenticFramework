# %%
import os
import locale
import modal
from agents.preprocessor import Preprocessor
from dotenv import load_dotenv
load_dotenv(override=True)
from hello import app, hello 
 
with app.run():
    reply=hello.local()
reply


with app.run():
    reply=hello.remote()
reply
# Out:
# 'Hello from Dallas, Texas, US!!'
